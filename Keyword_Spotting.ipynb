# %% [markdown]
# <a href="https://colab.research.google.com/github/mekaneeky/speech_experiments/blob/master/Keyword_Spotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gcloud auth login
# Out:
# Go to the following link in your browser:
#
#     https://accounts.google.com/o/oauth2/auth?code_challenge=ZZIBT_LyS0nBfjbIyaXGC4ppcQaPNQtkNVlyrfInfcI&prompt=select_account&code_challenge_method=S256&access_type=offline&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&client_id=32555940559.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth
#
#
# Enter verification code: 4/qwF4kl26ZNsNy_7Vq9xPWPjdCZ1PbBf2TAKxi89-JuVMzjdCVbC38dE
# WARNING: `gcloud auth login` no longer writes application default credentials.
# If you need to use ADC, see:
#   gcloud auth application-default --help
#
# You are now logged in as [alizawahry1@gmail.com].
# Your current project is [None].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %%
# !gsutil -m cp -R gs://nlp_keyword_bucket .
# Out:
# Copying gs://nlp_keyword_bucket/data_dir/Pump/ade5f91afb9847438ca09926a8c2762e_0a9845ddbedb42a3938ac68cb4132ec0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/ade5f91afb9847438ca09926a8c2762e_09a4c72cddbd409d9d4fbfafa9e21859.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/ade5f91afb9847438ca09926a8c2762e_38c54d10eba74cb8b63e1d638219f7ac.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/c4d4b1c359c74eadaf7e72a085ace673_388f52db33fe4901b8f2a7776fc35b94.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/c4d4b1c359c74eadaf7e72a085ace673_52d6306d252b43ceae94287eefd77a1b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/c4d4b1c359c74eadaf7e72a085ace673_53e95f8e06974fbd992bbf5edb7831fb.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/c4d4b1c359c74eadaf7e72a085ace673_5e58558c7ad14e00a255366a8c81d91e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/c4d4b1c359c74eadaf7e72a085ace673_7943ec5708a9472a894febef2b732405.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/ade5f91afb9847438ca09926a8c2762e_95e41d3d6e6548128e9ae06f92dfde20.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/ade5f91afb9847438ca09926a8c2762e_cfb04851792044b79cf4bcd1dbac54a6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/76bf74a44b174982acf93933778e7468_7c04863b75534cf8b9be5af30ef95ee8.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/76bf74a44b174982acf93933778e7468_9adf080613c5441e933cc84900d00472.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Pump/c4d4b1c359c74eadaf7e72a085ace673_dd273f04fdea4c3f9e464ff456b74b87.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/76bf74a44b174982acf93933778e7468_1e1dbd971f1645d5a10352577a39db12.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/76bf74a44b174982acf93933778e7468_9ddc527981eb40b7b9ea69e7ffc10ace.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/76bf74a44b174982acf93933778e7468_b334f6a503ff4e048e166a719ef9d0bf.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/76bf74a44b174982acf93933778e7468_b83bdb39cba347afb01c51f853dbb09a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/76bf74a44b174982acf93933778e7468_cc0173e67da54080a21e265cceb4ea36.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/76bf74a44b174982acf93933778e7468_ddd717e2f2dc484c9cd4d451edeace42.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/bbf989753de2460cb0eba290aefe457c_810531a37f284d1cb0c1d4e644c7cc7e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/Spinach/de74de0bc8504a48a249a0d92b8f0603_79bde6724ae1480886e9d1f15e1375b9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/abalimi/f0f07e05b8ff4f2abe294595c3c49030_04b28658531b467c82cd4b4b862d2a72.wav...
# Copying gs://nlp_keyword_bucket/data_dir/afukirira/c941f01b803a4ff3b8d18e2e3d4410b6_8220bcd5a21245f9a03ef3a8aadbe94f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/afukirira/e490626893ef45c388643f9b843027f7_456fe64cfcbf42548349b362d84ad8ba.wav...
# Copying gs://nlp_keyword_bucket/data_dir/afukirira/e490626893ef45c388643f9b843027f7_4d41d4d44d864c01a08f81406b0b4459.wav...
# Copying gs://nlp_keyword_bucket/data_dir/afukirira/f0f07e05b8ff4f2abe294595c3c49030_ed77b7f7f5c343de996204603ddc1e3b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/ade5f91afb9847438ca09926a8c2762e_30a063810b9d4b8b929771200d79d185.wav...
# Copying gs://nlp_keyword_bucket/data_dir/afukirira/fde68475bc6d49d8a24fe9d620093025_256111ca20c3427db3a7eaa87616d8f6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/ade5f91afb9847438ca09926a8c2762e_53b063e057d440779ccb8edf34ed092b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/ade5f91afb9847438ca09926a8c2762e_7b01182d165b4937ac74ecb550ed39c4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/ade5f91afb9847438ca09926a8c2762e_91c4c0693b0a411cad6fd4c4aa85c5f8.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/ade5f91afb9847438ca09926a8c2762e_c9a9d623b30f44fbbe6e3c8e6addd579.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/c4d4b1c359c74eadaf7e72a085ace673_1a725c7d132949fb94641c6344598b90.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/c4d4b1c359c74eadaf7e72a085ace673_3465633041034d9e84571d69c8969097.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/c4d4b1c359c74eadaf7e72a085ace673_55c3b74c20ae4c8d91e29cf4c79dd1dd.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/c4d4b1c359c74eadaf7e72a085ace673_7ff0f54128c841c89d9483281dae8bdb.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/c4d4b1c359c74eadaf7e72a085ace673_96f15ea44325472cacab7d3e5edc05ae.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/c4d4b1c359c74eadaf7e72a085ace673_d97c3eca65214328b2267c3e68c08647.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/c4d4b1c359c74eadaf7e72a085ace673_ea4b3363372c4e458b5d62011d17dc69.wav...
# Copying gs://nlp_keyword_bucket/data_dir/agriculture/c4d4b1c359c74eadaf7e72a085ace673_f7ddc4f68443481d9fabe3303aabf486.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akammwanyi/4db337b1ecbd4a67bbecbd503d74750a_35a794e6be974f4dba58d6734d2952e7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akammwanyi/4db337b1ecbd4a67bbecbd503d74750a_4ce4445bda6b4d0c97ebc5a5ead94ed0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akammwanyi/4db337b1ecbd4a67bbecbd503d74750a_52da450bbb074ea6a81202c122e72249.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akammwanyi/bde68c99036c4615af56639387cb7e0a_0f66740291584c1e95bcd7b36453eff9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akammwanyi/4db337b1ecbd4a67bbecbd503d74750a_ee9007e0cd6d4f1aa3d47266edbfbcd2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akammwanyi/4db337b1ecbd4a67bbecbd503d74750a_faec8d3547b7488da9d98eb581b45602.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akammwanyi/bde68c99036c4615af56639387cb7e0a_73089ebd0ecf4cf4a734045905bf9b6d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akammwanyi/fde68475bc6d49d8a24fe9d620093025_e602242b87354474b762ef6db0f960a1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akamonde/4db337b1ecbd4a67bbecbd503d74750a_175afe2119944cd4bc4040dc56a2d0df.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akamonde/4db337b1ecbd4a67bbecbd503d74750a_25966a3c66844e8aa3afe3350433e015.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akamonde/4db337b1ecbd4a67bbecbd503d74750a_5b139b4a22f140699d7eca0787106c3e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akamonde/fde68475bc6d49d8a24fe9d620093025_1fd7c84eeef547e4b6a69912ef999609.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4bf67566b0944663b741b361f12d80a7_0000750825db48158958cc325fdd3832.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4bf67566b0944663b741b361f12d80a7_14fe2e5b6dd347aba47e5d0c2d856a63.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4bf67566b0944663b741b361f12d80a7_191df2fc983846e9bacd624875fb6e3c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4bf67566b0944663b741b361f12d80a7_224dcd71534c4327bfb46446a934be83.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4bf67566b0944663b741b361f12d80a7_c396f6a785a24f60ad069e21520a2a75.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4bf67566b0944663b741b361f12d80a7_d5354d7a08174793b5224f7514be0bcd.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4bf67566b0944663b741b361f12d80a7_e3e848a61bc348169d1eb1631f597070.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_5ca0a6e55759426e8e3346892fff688e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_81efd02545764374b1a47f9e723de44f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_8bde79c5064944acabaed050d8eb7917.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_98f21d7d4b2c4284a697f7739c43c2ec.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_99361db951974a1fb637e80781a90655.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_c73f5c5a55004affb371e26f0b98f93f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_9b3e6859f5a243e788c640aa8da6c7ab.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_e3b0f4c86a3042b385e083ebe0e9a614.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_fabb35493fb640c394bf2aa55991dd0f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/4db337b1ecbd4a67bbecbd503d74750a_fba72859f30246a18e03c6e0d72fe57b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/9b1366c90e1841ddb2c8345c88a95606_4332f3e24e1b4aca84ae49f43ed768c0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akasaanyi/c5043d1a91124c3aa60750b78447e6dc_58e969a98aad44798c45233de7a66a1e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatunda/4db337b1ecbd4a67bbecbd503d74750a_188818bb650744559ea4478615e000df.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatunda/9df9771a87844acc8ba0c848dae61340_b0ebe4c0f1cb49fc83f8395011491718.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatunda/9df9771a87844acc8ba0c848dae61340_c8a1d9b404644d2d947388d3cba6f639.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatunda/bde68c99036c4615af56639387cb7e0a_9377cbbf558c4331b5e24cccfc2456e0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatunda/fde68475bc6d49d8a24fe9d620093025_db3111cccf364a518965994bd3a7aad3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatungulu/4db337b1ecbd4a67bbecbd503d74750a_08aef65083a7476ab8b61adcc76c6be7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatungulu/4db337b1ecbd4a67bbecbd503d74750a_39858e8329c940a1a1e390c5a8ec709d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatungulu/bde68c99036c4615af56639387cb7e0a_9af3a6f3337342e69c7957640c219673.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatungulu/bde68c99036c4615af56639387cb7e0a_2e181eeb6d9a4da18f31c8b244e49c2b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatungulu/bde68c99036c4615af56639387cb7e0a_cd387bd8658e4cfeb66561105a4cfd53.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatungulu/fde68475bc6d49d8a24fe9d620093025_536ef444a7df49edbe5d6dd0c2fae41b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akatungulu/fde68475bc6d49d8a24fe9d620093025_7ec17c7878e6405a9e9146d744c25db0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_58ed741cb9f345df8f22a1a1a98e4ef5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_591fb195d0934fd8bda6a222d99dcbd3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_684526db0bec4afb878d187a7d115398.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_7c1860df84cc41c68ad9937852e46afc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_a29cd8af0a3d4dae8d8fb4e22ded349b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_a810fbd8aad8449c9aa0483ec9f2b941.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_b11f7fadfb414eab8ba22db97e399b40.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_b2c043cdb1324301a395ff9cef16167c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4bf67566b0944663b741b361f12d80a7_fc81861fe4c64cb29daa523ddd1cd1f0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4db337b1ecbd4a67bbecbd503d74750a_54cbdf115f3c471f8a260da0c8efc694.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4db337b1ecbd4a67bbecbd503d74750a_237d5bd5bf0a4fc2991e18c08dddba7b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4db337b1ecbd4a67bbecbd503d74750a_6ad59814b30b495380e054641d4f6018.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4db337b1ecbd4a67bbecbd503d74750a_81485b4d22434262ab945015ed97fcb9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4db337b1ecbd4a67bbecbd503d74750a_8e22b1d87d5345738d514084a90eadad.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4db337b1ecbd4a67bbecbd503d74750a_ea669dfe235744989d76b126f15ce650.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/4db337b1ecbd4a67bbecbd503d74750a_ebc0e0901a224b0f8255d65a59c4b8bb.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/c5043d1a91124c3aa60750b78447e6dc_61460664f5ec4d60bf9d6a17870f8944.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/c5043d1a91124c3aa60750b78447e6dc_6d7e1a568b5b476e8fe3078fca17e867.wav...
# Copying gs://nlp_keyword_bucket/data_dir/akawuka/c5043d1a91124c3aa60750b78447e6dc_8c4b171763bc41508ca5fa4133d25e93.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakoola/c941f01b803a4ff3b8d18e2e3d4410b6_3ee3bfb9add847ddbd8c14acd05ae031.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakoola/fde68475bc6d49d8a24fe9d620093025_85a49819c0a441eb91addb08fe3169ae.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakungula/c941f01b803a4ff3b8d18e2e3d4410b6_7cdf110c56dc4b6db9099c8c6cd392f1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakungula/c941f01b803a4ff3b8d18e2e3d4410b6_c3732fcf24e844708e0ba943a41d177e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakungula/e490626893ef45c388643f9b843027f7_7634377e9359423ea0a4138b56dc7a65.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakungula/e490626893ef45c388643f9b843027f7_f32ddb30c27e402eaa4767246e9c9dc6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakungula/e490626893ef45c388643f9b843027f7_bde1157d3fdb46fb84bf1c55ad7a09c4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakungula/fde68475bc6d49d8a24fe9d620093025_85d5e3dda86543eeb47f6004eb714bd3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakungula/fde68475bc6d49d8a24fe9d620093025_e945d5e7e4d94b0c83701d960dd558bf.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amakungula/fde68475bc6d49d8a24fe9d620093025_ec9e92ef2efb4661b998834e836b1e57.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amalagala/c941f01b803a4ff3b8d18e2e3d4410b6_3133d630227b420b80db6e7dd73f413f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amalagala/c941f01b803a4ff3b8d18e2e3d4410b6_4e1205871b184d4188584451167923af.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amalagala/c941f01b803a4ff3b8d18e2e3d4410b6_ce42b377bdaa42248dd71944a542e3c9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amalagala/e1c884b3d2ca490a977d98ce25b0084f_57cc503c7fea47b7a433c4ab99272e02.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amalagala/e1c884b3d2ca490a977d98ce25b0084f_db733a3e8d654e9c8529c8212840a114.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amalagala/fde68475bc6d49d8a24fe9d620093025_746622850e534be48ffe945c55ddc515.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amalagala/fde68475bc6d49d8a24fe9d620093025_f3c24524f5574befaa34d7e803b2b2fa.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amappapaali/4db337b1ecbd4a67bbecbd503d74750a_cf839bf26f904c19ba0f606878e1c9ec.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amappapaali/bde68c99036c4615af56639387cb7e0a_2d7cbbad7b8d42b2aa1ba196628db5e7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amappapaali/fde68475bc6d49d8a24fe9d620093025_30dbf142ed6344268ccd52d044857374.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amatooke/4db337b1ecbd4a67bbecbd503d74750a_63ef8eb9fa2c4145bd7feb4ab6a76a78.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amatooke/9df9771a87844acc8ba0c848dae61340_de450358a0c946e688a053f2f478e703.wav...
# Copying gs://nlp_keyword_bucket/data_dir/amatooke/fde68475bc6d49d8a24fe9d620093025_d81ff00686f84c1d9cd085f507e03e53.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/76bf74a44b174982acf93933778e7468_51094b5a6fa247dfa8fb1aef949ed456.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/76bf74a44b174982acf93933778e7468_8ee6aad485e74ed1be06f003bb0ac0e9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/76bf74a44b174982acf93933778e7468_a7202b95c5e34768a058ee43d1f2666f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/76bf74a44b174982acf93933778e7468_173a319a27324e6dab46b5990d61b608.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/76bf74a44b174982acf93933778e7468_c6bf3f41a6f942a9b3cd200f04f3494a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/76bf74a44b174982acf93933778e7468_edce62a879314acdbdb6243613d44191.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/76bf74a44b174982acf93933778e7468_f48ea24d9da145d19edcecee8793b9a7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/76bf74a44b174982acf93933778e7468_fd262853d8c34fa0bcb41fc3fbf4b3b9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/bbf989753de2460cb0eba290aefe457c_1c0889cf3f94411baf5761547feea38c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/bbf989753de2460cb0eba290aefe457c_6e0e10de71984630a068a97c6dad7eb2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/banana/de74de0bc8504a48a249a0d92b8f0603_29032649482e459c97f32b9ee5256f74.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_34c1f9f7d5d34693aec2c359e0a8ca4a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/6968458cfdea4bf888343581d5ce6a5e_4b6885fbcf8f40b68624aa9ef816885b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_3991af4c4b4f40a28181a3edd0247d82.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_3c05af1213ef4a6c9fe3928da7cb4ec6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_9c1875462aa44632b81a6750ff7c38a3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_87c3410ae1f44defb6bdc1977a12bbea.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_abcf2aab04c945f49622fff745a3f96c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_ad690953507e4a8591d964c5e6af2d8d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_c179f6b6d78c4b7fa8f0a73fcd72075a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/beans/76bf74a44b174982acf93933778e7468_e040f7279b3d4ce6b61ae61593bdd05c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bibala/4ab1c4c479eb40f4b5632a7a96a08ffb_aea7d718c90b43a4b5c14c3f4d31424d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bibala/c941f01b803a4ff3b8d18e2e3d4410b6_57d5900c1e5647f6bebcbeacbeb487f9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bibala/e490626893ef45c388643f9b843027f7_d8af373102f94d81b31d306f98b77298.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bibala/f0f07e05b8ff4f2abe294595c3c49030_9fe78993e4e34d3c8e605d6a818922b3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bibala/f0f07e05b8ff4f2abe294595c3c49030_dec7e40b194747d0a6c3e56e8e2e9a00.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bibala/fde68475bc6d49d8a24fe9d620093025_05c7b1729fee44f6a63d7a1ea736d5d2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bibala/fde68475bc6d49d8a24fe9d620093025_958f8e9864ed4f96972243882dfc0252.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bibala/fde68475bc6d49d8a24fe9d620093025_c7913c19ead746828f06e19b9af48067.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bulimi/f0f07e05b8ff4f2abe294595c3c49030_1b7fba4b5bf04cc4adc789d6824dec2f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bulimi/f0f07e05b8ff4f2abe294595c3c49030_ecf7a4127ee54250be3e75f715593bec.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bulimi/fde68475bc6d49d8a24fe9d620093025_28d0a0ca2b4546299a70f199899451d3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bulimi/fde68475bc6d49d8a24fe9d620093025_39562dc0704c448aa2fa04ebee3e2b34.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bulimi/fde68475bc6d49d8a24fe9d620093025_dc2fff15f8f34904b108521e5d81bb70.wav...
# Copying gs://nlp_keyword_bucket/data_dir/bulimi/fde68475bc6d49d8a24fe9d620093025_e38021ca12a245eb8ddb27b1bc41bef5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/butterfly/6968458cfdea4bf888343581d5ce6a5e_5ac91c222a6a4a82860461bfeb1a405f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/butterfly/ade5f91afb9847438ca09926a8c2762e_0b53f2add19648c49dbe630f6f5022b3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/butterfly/ade5f91afb9847438ca09926a8c2762e_64673d3d31a8421895a883179f835502.wav...
# Copying gs://nlp_keyword_bucket/data_dir/butterfly/ade5f91afb9847438ca09926a8c2762e_72ccd620ab7740fba1bb0a5120547e68.wav...
# Copying gs://nlp_keyword_bucket/data_dir/butterfly/ade5f91afb9847438ca09926a8c2762e_d0f0b777eaf7430ca2a55cc7113f9dfe.wav...
# Copying gs://nlp_keyword_bucket/data_dir/butterfly/ade5f91afb9847438ca09926a8c2762e_d195632cc6674d6e84156581c551afbc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/6968458cfdea4bf888343581d5ce6a5e_56c9f40650a34b168d957cdfc1e1e730.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/76bf74a44b174982acf93933778e7468_19a8dfc2383a4c5eb18d743a2b3dd0ee.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/76bf74a44b174982acf93933778e7468_3bfc9ed90d144f079053460591e1c7a3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/76bf74a44b174982acf93933778e7468_566eb790ce7c42468ab91e701c635698.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/76bf74a44b174982acf93933778e7468_61ab7d4afbda449781087a822cdb2a4f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/76bf74a44b174982acf93933778e7468_769cebff7b1143548714c903f1340f43.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/76bf74a44b174982acf93933778e7468_ae6700e17a8a4d0bb7bec0a480d05a41.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/76bf74a44b174982acf93933778e7468_c678cc7d72f841eeb9d023c7abde8323.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cabbages/76bf74a44b174982acf93933778e7468_e6341f5654ee4f07a6c13e3139871b01.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/76bf74a44b174982acf93933778e7468_11846db159c8489a99ba0b8fece1d77f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/76bf74a44b174982acf93933778e7468_187ac44812b546a39f6f4a64797e2404.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/76bf74a44b174982acf93933778e7468_304b4dbb2ad64d40b610718623e1e419.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/76bf74a44b174982acf93933778e7468_a7b4580d33324def8f585105a550ce09.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/76bf74a44b174982acf93933778e7468_bfb810fbf291422aafd2a7d15ba79794.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/76bf74a44b174982acf93933778e7468_c9d76097427b41c49c981f3d5ce15d29.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/76bf74a44b174982acf93933778e7468_d12adf295fab437ab18c9c60a80add8f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/bbf989753de2460cb0eba290aefe457c_6cc6e0708ca04219affaad0c96e59a97.wav...
# Copying gs://nlp_keyword_bucket/data_dir/cassava/bbf989753de2460cb0eba290aefe457c_aeac056725a14e7aa72823a3a55b7c97.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/548c332e76b2497f8a2188337bbd9660_5d82d48653b34c17828b82a0c46761c1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/548c332e76b2497f8a2188337bbd9660_b74a8f7d4c944598bc281bcef056ae8a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/6968458cfdea4bf888343581d5ce6a5e_7ae0b0e944da45118ca9f9090b0f4e27.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/a08d60bd910d4ec2b7464d92fc5d657a_fd637c0f3f01400c8cee2a367120ef30.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/ade5f91afb9847438ca09926a8c2762e_20b6137902f847378fbd7304ab8fbf18.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/ade5f91afb9847438ca09926a8c2762e_489350920d0c4455a394bb3f9dac7e01.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/ade5f91afb9847438ca09926a8c2762e_5dcd188011fc4648a80dc9ba62582fe0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/ade5f91afb9847438ca09926a8c2762e_7651991417314cb28d6a03b693709183.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillar/ade5f91afb9847438ca09926a8c2762e_d73f5630a90343cfb2bea961103cba04.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillars/6968458cfdea4bf888343581d5ce6a5e_d7df063af3b945b0907e11893de45850.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillars/a08d60bd910d4ec2b7464d92fc5d657a_6c4eb96fa20948989595a80c4d14d2c1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillars/ade5f91afb9847438ca09926a8c2762e_53f0969f27f8485d952b7c47db9c658a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillars/ade5f91afb9847438ca09926a8c2762e_541fc0a6687340d68c92536c38f7431b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillars/ade5f91afb9847438ca09926a8c2762e_6626ce5f93d940de9724fb47299076e1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillars/ade5f91afb9847438ca09926a8c2762e_681ef460fae24f81b67561765c407f44.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillars/ade5f91afb9847438ca09926a8c2762e_aa86cb5297504834a790bd8c39d0c76c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/caterpillars/e3b576fc9df84672873753371b2aff0b_bc1e993db95842fda07a1b573174032f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/6968458cfdea4bf888343581d5ce6a5e_bbd08770dd7c41f889c2c5434f4cafde.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/6968458cfdea4bf888343581d5ce6a5e_d8f2f3450e51414fab596891c7115c3f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_01e3ac3e18f84ea7a56fc40cc253951c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_1f983c191a70408eb2e360c00ef06c03.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_2b8b24fabc38420294c2406015208ede.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_525bf22c73804431ab1c6e74ffea742f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_42a070f11c57497e94738349ac80ee00.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_6671dfce3ae745698bfcf9b5e7c5c135.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_d7b5d56d1c774ac48e1d01f5d6c76605.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_dc41996b38004720b029f21d9f2e5282.wav...
# Copying gs://nlp_keyword_bucket/data_dir/coffee/76bf74a44b174982acf93933778e7468_fa121a7c48b841dbb792eca337f752bd.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/5b8d41d3b089423b87b05a71d06cfea1_bfa7c6c1e9d6409980887dd1dd5f28de.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/769c386ee1d4413282564bbf93527a27_d907d7e94eef4eb38ce993f8c12eb79b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/ade5f91afb9847438ca09926a8c2762e_2ff9b843dfbb4367b3803440bd50d366.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/ade5f91afb9847438ca09926a8c2762e_0d5f51c0b9014266b462500b70d7ec89.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/ade5f91afb9847438ca09926a8c2762e_8043f010917b4ddcba2a9e08297fa1d8.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/ade5f91afb9847438ca09926a8c2762e_9b7323c9024b43cfbcefe5bc3ee3670b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/ade5f91afb9847438ca09926a8c2762e_bc827eed7dda4606bf4c8e1b6f309911.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_1805134bcdcc4af8a0b260faae31b6ef.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_21cac0865d394b5abcf01e8492340b5d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_22452f9ba55d423daab887cc0d6c86a4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_7345ce924070420f966fdb731e4452c5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_45b53238104c403598c5ad238f99b0d1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_76dc55dab0d54c5cb13e6d5831f4e801.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_8d54bd54a4b74b1f95ad7f166d4dba74.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_f401856f836e484cb59344ddd4d0e363.wav...
# Copying gs://nlp_keyword_bucket/data_dir/crop/c4d4b1c359c74eadaf7e72a085ace673_fe4e2f4058564679b8d51f80ba85557a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4bf67566b0944663b741b361f12d80a7_10348ef6879e456d8b3c4d3e741a8635.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4bf67566b0944663b741b361f12d80a7_1bc5778fff864983a6d06b325c41928d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4bf67566b0944663b741b361f12d80a7_1f8c758aae6648a188fb79d4fafa411d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4bf67566b0944663b741b361f12d80a7_39cee83591274654a4384cca18486217.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4bf67566b0944663b741b361f12d80a7_64c3d892c4284d3b90b74ef640958d11.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4bf67566b0944663b741b361f12d80a7_9a61a665a3d74ffca0379a4a6da04e86.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4bf67566b0944663b741b361f12d80a7_9b04f08862734fc0806b838d37a11645.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4db337b1ecbd4a67bbecbd503d74750a_08d419fe416c469ea79b12a77cf5701f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4db337b1ecbd4a67bbecbd503d74750a_7182fa1c6bd64fa6823b8150ba685ae5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4bf67566b0944663b741b361f12d80a7_a31bfdc8ad7842b6b45c644b7be33998.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4db337b1ecbd4a67bbecbd503d74750a_87834abe301748a79e76abc655f2a93e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/4db337b1ecbd4a67bbecbd503d74750a_eb405a82677d431084cff49b5818adb0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/9b1366c90e1841ddb2c8345c88a95606_0c9cb0969eb44dc491477c3f3e921944.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/c5043d1a91124c3aa60750b78447e6dc_0bb4edb48805404781a3257fcc548c31.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ddagala/c5043d1a91124c3aa60750b78447e6dc_d8efdca7c98246b5bf2a110c82cb397e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/6968458cfdea4bf888343581d5ce6a5e_5393f5df2e0046a6b36c21cae929a405.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/ade5f91afb9847438ca09926a8c2762e_942b3a0c446b4dcb94c20512cb6955c9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/ade5f91afb9847438ca09926a8c2762e_be9bb3502bd946b2be740b616a38b16e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/ade5f91afb9847438ca09926a8c2762e_d4bde3ce08aa49d7a09153a7906c372b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/ade5f91afb9847438ca09926a8c2762e_d56d234f863e445dabb1e1e91f425f8e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/c4d4b1c359c74eadaf7e72a085ace673_084248e30965481fa5d5d5ea4508cf3b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/ade5f91afb9847438ca09926a8c2762e_e573e8b33eff4c9581d2dfe53b47b9f6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/c4d4b1c359c74eadaf7e72a085ace673_1b2c0cf7087b40e39663b43f708ca5cd.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/c4d4b1c359c74eadaf7e72a085ace673_271ea92c08da4757985230e3c4a8825b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/c4d4b1c359c74eadaf7e72a085ace673_2e245b58639b4261a1056ca9b64dc52d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/c4d4b1c359c74eadaf7e72a085ace673_8bc32c880d1741e096e6f912cde60f7e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/c4d4b1c359c74eadaf7e72a085ace673_8f6cd9ab3a8a4e158b374ab15927e209.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/c4d4b1c359c74eadaf7e72a085ace673_c96d3e46bfa94e5bbc555a903dde2625.wav...
# Copying gs://nlp_keyword_bucket/data_dir/dig/c4d4b1c359c74eadaf7e72a085ace673_ed84ad5fd58c49ff87cc4062b53b405c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/disease/ade5f91afb9847438ca09926a8c2762e_11b45d1ff73748188113a3076675347b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/disease/ade5f91afb9847438ca09926a8c2762e_9e82f33fd0fc41c5bb1bc65d85cc48b3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/disease/ade5f91afb9847438ca09926a8c2762e_a2f0377c3e9442c581d5c751a5e6282a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/disease/ade5f91afb9847438ca09926a8c2762e_d4016f4ad34e452386d82ea0263bfd71.wav...
# Copying gs://nlp_keyword_bucket/data_dir/disease/ade5f91afb9847438ca09926a8c2762e_e929ac4edac34384ad15ed37f2ef053f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/disease/e3b576fc9df84672873753371b2aff0b_679377c1270143f6814be8e7b5e98f1b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/doodo/4db337b1ecbd4a67bbecbd503d74750a_15cfb4da94904beeafd290301c9a3ae7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/doodo/4db337b1ecbd4a67bbecbd503d74750a_0b9bb148a34e486d8bd3525be00c7d7b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/doodo/4db337b1ecbd4a67bbecbd503d74750a_74d5b0e934fd48e39ea1c4f4f216c76e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/doodo/4db337b1ecbd4a67bbecbd503d74750a_c2e11ca7a4234a66aa2a7bb3886efb39.wav...
# Copying gs://nlp_keyword_bucket/data_dir/doodo/bde68c99036c4615af56639387cb7e0a_4b60c0fa902c4ca982275a32400cc117.wav...
# Copying gs://nlp_keyword_bucket/data_dir/doodo/fde68475bc6d49d8a24fe9d620093025_b116dcb7f17f4e0ab7aa611fbc664932.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/ade5f91afb9847438ca09926a8c2762e_6c4e0b7b79db478ea5b110fe3506a763.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/ade5f91afb9847438ca09926a8c2762e_75adcc7b70d049679fc5b515285f4d1e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/ade5f91afb9847438ca09926a8c2762e_923585bd86a04436af9feed25fe4d63e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/ade5f91afb9847438ca09926a8c2762e_d7a199d57b034299ac8d609cb71ce11e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/ade5f91afb9847438ca09926a8c2762e_dd8a1cc0d521413c8c08fd60b72ce486.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/c4d4b1c359c74eadaf7e72a085ace673_310c3734210f44429ce271276b57e97f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/c4d4b1c359c74eadaf7e72a085ace673_35eed6e944d54acf8ab8bc4cc7231ae3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/c4d4b1c359c74eadaf7e72a085ace673_39f11c827ee04345a40e0b262b04b337.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/c4d4b1c359c74eadaf7e72a085ace673_8c2a17e380a746139d45ca97f69c6a16.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/c4d4b1c359c74eadaf7e72a085ace673_c0c30337bd224c40845dfdb889a84032.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/c4d4b1c359c74eadaf7e72a085ace673_ebb5c069b8274922812200c975af8866.wav...
# Copying gs://nlp_keyword_bucket/data_dir/drought/c4d4b1c359c74eadaf7e72a085ace673_f20442d4725d4a74a297b64c75918ec4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebbugga/9df9771a87844acc8ba0c848dae61340_9444d126d6fe4e20834a10ca0d6f644b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebbugga/fde68475bc6d49d8a24fe9d620093025_68cac55560fc477ea52fff70bf412ef8.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebibala/c941f01b803a4ff3b8d18e2e3d4410b6_13015d479a224f688ac68e651b956433.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebibala/c941f01b803a4ff3b8d18e2e3d4410b6_ad6816a206e24ffa9552bb02d23b1e75.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebibala/fde68475bc6d49d8a24fe9d620093025_b5d2dfc3615e4306b76ecef5914330f5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebibala/c941f01b803a4ff3b8d18e2e3d4410b6_caf227dc0e8048ad838ec521af04fc28.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_00a1c9b033ce4981b2ae791af1f80862.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_0e51a40af3534d888de6de843b779999.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_417d6b14abc343f3b1460f57f75f5389.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_66cba417c27e4f6b87e1c3cef6ef1a60.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_65cdabfdfb1c4235939b96b1c6d70aee.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_7133b893d49b42f6bb7a721e8400ac4d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_8b1c6ef60c4c46e799be2137d0f3fddf.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_adad2184f3454e59ad4f1ebdacd2b5fc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4bf67566b0944663b741b361f12d80a7_c3af991beac6420eb0a71d532ed59428.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_136cfdfe8a264091b6586a6ac3ec470f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_2a2b975e8d2a48da96398f5d07315b17.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_50f6ab3bf8544c669f5200ea57569b3a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_5f538cedcd4d46cebdd395fe5d3e5142.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_6cf19f05bf8242f580b11207748c10ba.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_707a2d7863a34e9f92b53868949fe3cb.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_836b949d18b04832876ff0ccace764a0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_ca9e3f3693164fb6aa6f6a103295b8b9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_d1bb35d0f8654856926abb25ec74f9c8.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/4db337b1ecbd4a67bbecbd503d74750a_fcb433db10c149c785876b03843ceb98.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/9b1366c90e1841ddb2c8345c88a95606_55bc411c707b42feb92d09b766c8c654.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/9b1366c90e1841ddb2c8345c88a95606_7305eb4aa7934e759b53ba0b8e36e397.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/c5043d1a91124c3aa60750b78447e6dc_3447fc069c424500b7e681bb31348ae2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebigimusa/c5043d1a91124c3aa60750b78447e6dc_8cfc5585c2604187958496b1f2ecad2b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebijanjaalo/4db337b1ecbd4a67bbecbd503d74750a_f840466c19a74fd4b9dc7c763fd7fdb3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebijanjaalo/fde68475bc6d49d8a24fe9d620093025_eb2531504c054600bc448e2f8908b7f2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebijjanjalo/4db337b1ecbd4a67bbecbd503d74750a_ba8ac0d4fc01444c91c59383c1c3eb20.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebijjanjalo/9df9771a87844acc8ba0c848dae61340_64212fa3bd2d41cf9412ec37136b5d37.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebijjanjalo/fde68475bc6d49d8a24fe9d620093025_263ce6747e5243f19b2224cd3624199f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikajjo/4db337b1ecbd4a67bbecbd503d74750a_0702452315184c848331ef480e25ce57.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikajjo/9df9771a87844acc8ba0c848dae61340_3c038288bb0444fdb9e09d0118cb3f37.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikajjo/fde68475bc6d49d8a24fe9d620093025_67aa77a837944ed58d2ef4eb4b559e5f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikajjo/bde68c99036c4615af56639387cb7e0a_10963ed13e21485d93a326705ca410d5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikajjo/fde68475bc6d49d8a24fe9d620093025_967e1807cf134b4e853fda0a2393c8de.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikolo/f0f07e05b8ff4f2abe294595c3c49030_dff7a9cca6b14c119804d48002e89813.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikongoliro/4db337b1ecbd4a67bbecbd503d74750a_1f9b29ab19f64320a4bd122486b41a65.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikongoliro/4db337b1ecbd4a67bbecbd503d74750a_8ac59499e378491196314b3bdba6ab31.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikolo/fde68475bc6d49d8a24fe9d620093025_a3bcbf491dd8471b93cb387233eec71c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikongoliro/bde68c99036c4615af56639387cb7e0a_73863cf882514d94a7440730091d7288.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikoola/4ab1c4c479eb40f4b5632a7a96a08ffb_77f48c3f47234878a12e6a9ddd7a7380.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikoola/c941f01b803a4ff3b8d18e2e3d4410b6_0a61332654904938a1d774cbfd3f31d9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikoola/c941f01b803a4ff3b8d18e2e3d4410b6_33fe5850d62c4a2a85074576f26a6028.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebikoola/c941f01b803a4ff3b8d18e2e3d4410b6_d53ee1024c7b4cfd9d3e45a8872d5560.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebimera/c941f01b803a4ff3b8d18e2e3d4410b6_0164929dae7d498f84a80b514ce5f8fe.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebimera/c941f01b803a4ff3b8d18e2e3d4410b6_5e7efe6767f54cad827c3e2959886012.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebimera/c941f01b803a4ff3b8d18e2e3d4410b6_820613e8c31848828582c41c05338498.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebimera/fde68475bc6d49d8a24fe9d620093025_e69fa487a1fe4349a6736b19c9b678ef.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebimera/f0f07e05b8ff4f2abe294595c3c49030_45632882d780455dadf282583d85e27b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebinyebwa/4db337b1ecbd4a67bbecbd503d74750a_6a734db502574759bf266ae388a99008.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebinyebwa/4db337b1ecbd4a67bbecbd503d74750a_9a507659f44b41f5b5672b01f58aacfa.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebirime/4ab1c4c479eb40f4b5632a7a96a08ffb_1ee6c2c4ae634788b8b504952f5570ea.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebirime/e490626893ef45c388643f9b843027f7_3937269a634d4c43973f6060c691cb6d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebirime/fde68475bc6d49d8a24fe9d620093025_665b5af36c9748de9b1186e3fab51f6d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebirime/fde68475bc6d49d8a24fe9d620093025_9fb1b0d59c7d4207bf8627e236a6a610.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4bf67566b0944663b741b361f12d80a7_0ef2912b9a834c7abc5b270a2b215e5c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4bf67566b0944663b741b361f12d80a7_2db4aaaac64c4c12bd85fd55debaca5f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4bf67566b0944663b741b361f12d80a7_33284a6fd87f44e2b41d97c716f5f117.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4bf67566b0944663b741b361f12d80a7_56804b09e13242f2a2bb562f23b41830.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4bf67566b0944663b741b361f12d80a7_72e639c745fa4b49a8bae3b5ea6588d6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4bf67566b0944663b741b361f12d80a7_98be649fd9494e30b2f2e52f7e089f6b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4bf67566b0944663b741b361f12d80a7_ae541d51716a4f35b33b43019f493da0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4bf67566b0944663b741b361f12d80a7_c6e72cb6e5e9432498292302035d5009.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4db337b1ecbd4a67bbecbd503d74750a_398390ec180c4a7bb87fcb40eefc6122.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4db337b1ecbd4a67bbecbd503d74750a_470996ded17f455aa2ea9557c0d0712d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4db337b1ecbd4a67bbecbd503d74750a_cbb9cac2a0084e06998d4a90ad834c5c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4db337b1ecbd4a67bbecbd503d74750a_ec74a902c9964a5b906fe2befb9440f8.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/4db337b1ecbd4a67bbecbd503d74750a_f2c653024b9f411680b77269a11156a1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/9b1366c90e1841ddb2c8345c88a95606_58b534f55527435cb10662652feda7c4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisaanyi/c5043d1a91124c3aa60750b78447e6dc_5dd944b3b11147c9aab0cb727997442d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisooli/4db337b1ecbd4a67bbecbd503d74750a_0d641e381b9b44aeb0bada7d6a5327c4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisooli/4db337b1ecbd4a67bbecbd503d74750a_723025e889ea4d349534dc063a90a9c4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisooli/4db337b1ecbd4a67bbecbd503d74750a_b033ef74e1ab42ca87fd0bbbc7654f7a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisooli/4db337b1ecbd4a67bbecbd503d74750a_d2d4b05de6214b839bc317dad9f10737.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisooli/9df9771a87844acc8ba0c848dae61340_75968341a14f400f9ceeb60a72c585a5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisooli/bde68c99036c4615af56639387cb7e0a_1949bd21a9564f9897081db9b147f89f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisooli/bde68c99036c4615af56639387cb7e0a_89d8d3df8e384ab18dea385bb414b91a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/4db337b1ecbd4a67bbecbd503d74750a_362d00baecc44383887855f14186096b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/4db337b1ecbd4a67bbecbd503d74750a_83509de545b241249fe80d9bb0daaf6f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/4db337b1ecbd4a67bbecbd503d74750a_95b5445535d04e36b034129ef8f3cd81.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/4db337b1ecbd4a67bbecbd503d74750a_b3fb7cdef7424ce59bd2a6535dd18c1d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/4db337b1ecbd4a67bbecbd503d74750a_cafafe27dbe74821982f898cfb252c3d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/4db337b1ecbd4a67bbecbd503d74750a_fc4bdebe59724ffebdcb4ef44eb2f0d9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/9df9771a87844acc8ba0c848dae61340_8dfb95d2c27c4215ba5f9e3dc31ebdce.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/9df9771a87844acc8ba0c848dae61340_e6cd481a9e6544d4b8cd892b56e22f25.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/bde68c99036c4615af56639387cb7e0a_5d01868eba624c489c867bad012fe47c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebisoolisooli/bde68c99036c4615af56639387cb7e0a_9edc2c0192934a038eda93c6e98cd4fc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebitooke/4db337b1ecbd4a67bbecbd503d74750a_2b98a10cfce34b169db3f099470e7986.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebitooke/4db337b1ecbd4a67bbecbd503d74750a_df5c8133e65144dcbe6e2832eb1554ea.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebitooke/4db337b1ecbd4a67bbecbd503d74750a_ee8c5e6a33024f78b9491f61d432521d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebitooke/bde68c99036c4615af56639387cb7e0a_0bdc94659ad54ff8acb736dd423a00ad.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebitooke/bde68c99036c4615af56639387cb7e0a_1d2ad54b5e3d49019e51868814c2c491.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebitooke/bde68c99036c4615af56639387cb7e0a_d2aacf45f9fd4402baba5d924d385870.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4bf67566b0944663b741b361f12d80a7_187f5a0094e94f19b9c461b66f43ca62.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebitooke/fde68475bc6d49d8a24fe9d620093025_a2262f9bdedd401ba9521c227e6bfaea.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4bf67566b0944663b741b361f12d80a7_678013c724b844c0a3ed311ceb3b6ec2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4bf67566b0944663b741b361f12d80a7_a0346fa54c84448a91d79fd77759d7ff.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4bf67566b0944663b741b361f12d80a7_e4f68353faeb45ffb6bde1cc2f9b9260.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4bf67566b0944663b741b361f12d80a7_ea93cfdf7cfc4de087d343c8296d6186.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4bf67566b0944663b741b361f12d80a7_f8a1757ba2f344dd9e05f7ebcb6cd76b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4bf67566b0944663b741b361f12d80a7_facca89abca84eac85c2f427bbd2f98b.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4bf67566b0944663b741b361f12d80a7_fe1a3a83004c4be8b43db382c6ef8ae5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4db337b1ecbd4a67bbecbd503d74750a_28d73ac150724ebc98bac1895caabfb3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4db337b1ecbd4a67bbecbd503d74750a_3269c233f2f94a8383ee6910454b78b9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/ebiwojjolo/4db337b1ecbd4a67bbecbd503d74750a_42bc5918751149db9bb67de5258143b3.wav...
# ...
# Copying gs://nlp_keyword_bucket/data_dir/sow/ade5f91afb9847438ca09926a8c2762e_5ba77011bf20457e9256662542a92e17.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/ade5f91afb9847438ca09926a8c2762e_d8e8f3c71041473eb5096b174a10684f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_1831662b48c0440fadca386078671391.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_18d646caa1ee43739d5bb37735445407.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_714dc6f10692432888ee10b365b6a7f6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_66df8ff0d92648568cdfa91e71ad815e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_bf0626278fd34f02bfce3f3c9480c7a4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_c8f4e163c17d4560a9986be7294e5702.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_cf2887ec19ca4681a265016c5134a5f3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_d73d70fd5d8846b78032889f6712d6eb.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_f2553dc90e1b4ae5ab085bd1336d8444.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sow/c4d4b1c359c74eadaf7e72a085ace673_f85812b564f64edbb2c43e1eb884e1ed.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spray/6968458cfdea4bf888343581d5ce6a5e_6be94ea1bd6843758a302b8cb32ce2b7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spray/6968458cfdea4bf888343581d5ce6a5e_aa1aa3f7cbc34743b999281e0896bc09.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spray/6968458cfdea4bf888343581d5ce6a5e_e0926d99987545a58dc0af87f02e6abc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spray/ade5f91afb9847438ca09926a8c2762e_19cb18fc686949b3b5dc7aabdb98f5f4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spray/ade5f91afb9847438ca09926a8c2762e_91174eac19994229b34a23cd8406d8af.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spray/ade5f91afb9847438ca09926a8c2762e_c90a9c94aa0543a79a6ed9e05364a8a2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spray/ade5f91afb9847438ca09926a8c2762e_d4add8a0e9684875a8f26a621a003c40.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spray/ade5f91afb9847438ca09926a8c2762e_fb81a02ec70c4a5c816ee5968de9689e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spread/a08d60bd910d4ec2b7464d92fc5d657a_06b1216fd80f436899680f287febfe60.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spread/ade5f91afb9847438ca09926a8c2762e_50eb1148232b42a2b056490b7b2b2e6c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spread/ade5f91afb9847438ca09926a8c2762e_53a69f3137154c3f89e4176672676421.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spread/ade5f91afb9847438ca09926a8c2762e_8b53edcbb8274cd2b921e6802b040530.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spread/ade5f91afb9847438ca09926a8c2762e_9d473932b81b443b86da9dcdd6a7a3c6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spread/ade5f91afb9847438ca09926a8c2762e_cb09a5da5e00462e8e74235d46180c94.wav...
# Copying gs://nlp_keyword_bucket/data_dir/spread/e3b576fc9df84672873753371b2aff0b_cba4f635c35d42edbd187208ac268166.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/ade5f91afb9847438ca09926a8c2762e_0a4c4aa514c146c5ad615d07e2833770.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/ade5f91afb9847438ca09926a8c2762e_5e6b919ea3a64d64900f3e1f7eaffded.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/ade5f91afb9847438ca09926a8c2762e_8bb14641c47f414bb0e94e2fd8342f57.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/ade5f91afb9847438ca09926a8c2762e_d38f1ce43a1241fbaf8c808844db415d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/ade5f91afb9847438ca09926a8c2762e_fece3a57f4294ce6b2205c28ba26f07c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/c4d4b1c359c74eadaf7e72a085ace673_0278ea0bd9bb4182864411ecc48d75f1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/c4d4b1c359c74eadaf7e72a085ace673_3ac4a27ea8d74efdb6862b4c96430904.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/c4d4b1c359c74eadaf7e72a085ace673_48571deaa0a24d6ea111f98e8d916af9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/c4d4b1c359c74eadaf7e72a085ace673_8a3c9f1ff5e64c0ca1476456bbb9956f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/c4d4b1c359c74eadaf7e72a085ace673_b3d0836be75845eb8a603a8ac55050c5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/c4d4b1c359c74eadaf7e72a085ace673_e37ceaf21a4c452a8e67d401ac4494bb.wav...
# Copying gs://nlp_keyword_bucket/data_dir/suckers/c4d4b1c359c74eadaf7e72a085ace673_e959d331535a46dcb7f5da6f335bdb90.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_2cb8d9447c864d689932c355d4509c9f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/6968458cfdea4bf888343581d5ce6a5e_c7a0254582bf4513975333dd22b80e8e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_2d1c028a71734941974a44ace4bb2311.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_4cb2c294b7d342f387583ae1801703ee.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_6a2df830a9184b0087036bcfacfff55a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_9bb70e6eb6f6409bad92190325c10b71.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_b48129ef8f8b4ad18d423b42572a7168.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_ccae2f4779e3483c90f49c3b2a981498.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_e7be1b15aa3448bdb9622e9607bb2c79.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sugarcane/76bf74a44b174982acf93933778e7468_ef879973c2974e52a25c84126af64c02.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sukumawiki/76bf74a44b174982acf93933778e7468_086853c6e9ce4c0c8755df6a1f6820d1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sukumawiki/76bf74a44b174982acf93933778e7468_2519915f6c80491b9254aa5baba9f453.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sukumawiki/76bf74a44b174982acf93933778e7468_46cd888918c74396b3ff3197a5eb0cb6.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sukumawiki/76bf74a44b174982acf93933778e7468_63f14d6bf3524c6394899844b42dde7c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sukumawiki/76bf74a44b174982acf93933778e7468_6d2e0c7a9b524a948c4f44783f0fdcdc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sukumawiki/76bf74a44b174982acf93933778e7468_7335cd4a936d429784f9d295e90659e4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sukumawiki/76bf74a44b174982acf93933778e7468_e0a2b2d58f7c4826ae80c0837991ceb0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/super grow/6968458cfdea4bf888343581d5ce6a5e_1b289287746b475e875bf78c50b78d00.wav...
# Copying gs://nlp_keyword_bucket/data_dir/super grow/ade5f91afb9847438ca09926a8c2762e_1191fee3c2e1471eb3f298bea770a53e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/super grow/ade5f91afb9847438ca09926a8c2762e_28c0d7f7489640c887f69d76f4912bae.wav...
# Copying gs://nlp_keyword_bucket/data_dir/super grow/ade5f91afb9847438ca09926a8c2762e_6baa9dd66c7c42a38b396ae8f36a69ba.wav...
# Copying gs://nlp_keyword_bucket/data_dir/super grow/ade5f91afb9847438ca09926a8c2762e_719586a8ca6d415ab9d3c09c7a8c97cb.wav...
# Copying gs://nlp_keyword_bucket/data_dir/super grow/ade5f91afb9847438ca09926a8c2762e_af42fbbd9fcd469e89c89527e5fd8c55.wav...
# Copying gs://nlp_keyword_bucket/data_dir/super grow/e3b576fc9df84672873753371b2aff0b_04ef4f748b2741d791108b9ca82773ee.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/76bf74a44b174982acf93933778e7468_150911e76c3349dca794d678316142bd.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/76bf74a44b174982acf93933778e7468_1bc1020d0c9e456c8ab131d0f461bef0.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/76bf74a44b174982acf93933778e7468_4af7af91fa994317bc71fea14e98562a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/76bf74a44b174982acf93933778e7468_53745d8cf2cd4ba8bb3dcb2157451aa4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/76bf74a44b174982acf93933778e7468_6b4d874bf3b549769e8bf55ee75e4315.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/76bf74a44b174982acf93933778e7468_a1b2783b5476417aafc497ed1ccf1019.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/76bf74a44b174982acf93933778e7468_d7bdea4005a0439e9bf3c4d5d33e9f85.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/76bf74a44b174982acf93933778e7468_f0a6baa0961749119507d3ef1535fc32.wav...
# Copying gs://nlp_keyword_bucket/data_dir/sweet potatoes/de74de0bc8504a48a249a0d92b8f0603_39e7003df61743a7804983b2643ca2d9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_15851ffd87a14f2c84a0937f37aeedb4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_4e0858eddc154e3cb1ac55ace85c4605.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_805e10fc3983450482b2f980984a0cd2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_c11194d5dcc6471ba8c634223549b257.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_9e998f691ca74c8f8a9548531ab8e7f2.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_a79fb6cd52364b4c895eefd3766b875d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_c9d2f2dcb3f14a41a80096d290bcd3bf.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_dd90ea75d64245aeab7a98a8ed1b199d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/76bf74a44b174982acf93933778e7468_f5da417da31541188b4e1f30e3541086.wav...
# Copying gs://nlp_keyword_bucket/data_dir/tomatoes/de74de0bc8504a48a249a0d92b8f0603_16fae46e4f44461fa049c9df86815e77.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/6968458cfdea4bf888343581d5ce6a5e_8a09c58ba9ef49c998e83197d5aa728f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_0f6e5088d1d44b7ca07b0feea28f65d1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_597f0867c74f4fbc9d53e6321d0a8fbc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_5a5ea9ac44ed4779825afa0210ddbdf3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_70c7a07062ce48ee9e07ec3a0ee3d7be.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_9e979fdcf4024943bc936f22e4ae3811.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_bac27df9cd314e9db31c2ca760e9abc3.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_bbb3ca6dbc8e4f83bccebbc876dd6170.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_d2d853e81b5c4ebbae0e1f76229872f5.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_d2dde94b3af8422780b49ab4fd5041d8.wav...
# Copying gs://nlp_keyword_bucket/data_dir/vegetables/76bf74a44b174982acf93933778e7468_f1a067f35081484dae4d4663c9ad85fd.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/6968458cfdea4bf888343581d5ce6a5e_b0dada0504f94c109f2612cb53c95f21.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_09c80c744ee249c1b65b22ee43b14534.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_2067e13e7d5e481cb862d51415cbcc2d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_3b1f2a1bb7534431ac5dcb73aedf6d6d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_4899106934674d3388965342c1d88e35.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_6d837f1bf3594ce0a13c7d2b5cbe73ff.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_bae859ffdbea4ddeb98913c855d15330.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_bf0e108eb5c148599d49ebf168d90f5a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_cc64be665daa44a88e8ca8b6a4963c25.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_daa11031ea10470cbe4b81d1b498eda7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/76bf74a44b174982acf93933778e7468_fd2cf3f921ca43ee8c0881fbd7bd9cf7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/bbf989753de2460cb0eba290aefe457c_9a8c37fed18842479f3e280fa265f4a1.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/bbf989753de2460cb0eba290aefe457c_dee4de3871574f61a68911d8412a0acc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/watermelon/bbf989753de2460cb0eba290aefe457c_e89d7682431d4b5f92deb3f47c2b700a.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/6968458cfdea4bf888343581d5ce6a5e_093639d6b9b341a1909c10ecfda1f5b9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/ade5f91afb9847438ca09926a8c2762e_0586c7701ee94a6c924973c3cec9987e.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/ade5f91afb9847438ca09926a8c2762e_0c5b2efffd924f7da754858263c5a985.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/ade5f91afb9847438ca09926a8c2762e_4ba8b6123b0b4d63b79f099ed2220953.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/ade5f91afb9847438ca09926a8c2762e_59154c806f354c7fbfed17eca879036f.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/ade5f91afb9847438ca09926a8c2762e_9454db65e87b44c88f66de763e4522f7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_08f2b4a934db4683a7f819ba5422a677.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_0aaf9289f2f54162be6e000ffad3d871.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_192b0eae34384411851d04f3d218e278.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_5d6ce562d9524417b04c9a0f1d64418c.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_67310b4150514ea38a1dc2059b43d298.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_6883eddf5a724426b4ac4e9554f86b9d.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_85ada079afbd4a5ca3b562882d9eb5b7.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_a5ef69579aea4ea1a24994c22914ec42.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_b61c8e8972094b2f8f1112eb06341fe9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/worm/6968458cfdea4bf888343581d5ce6a5e_53b705031111479ab937cbafe24850d4.wav...
# Copying gs://nlp_keyword_bucket/data_dir/weeding/c4d4b1c359c74eadaf7e72a085ace673_e3f94bd96a4e49a4922bd92f6f0e1399.wav...
# Copying gs://nlp_keyword_bucket/data_dir/worm/ade5f91afb9847438ca09926a8c2762e_5f689db2cb784d3dae252a1998344bc9.wav...
# Copying gs://nlp_keyword_bucket/data_dir/worm/ade5f91afb9847438ca09926a8c2762e_a29c675540cf40a5a8284ecf24a7daaf.wav...
# Copying gs://nlp_keyword_bucket/data_dir/worm/ade5f91afb9847438ca09926a8c2762e_abe89e409140439da5aa06b7f46680fc.wav...
# Copying gs://nlp_keyword_bucket/data_dir/worm/ade5f91afb9847438ca09926a8c2762e_b58dc2d2642b43cb92c07547b9862c65.wav...
# Copying gs://nlp_keyword_bucket/data_dir/worm/ade5f91afb9847438ca09926a8c2762e_e61d74c1b73b490fbec19292d0b034c5.wav...
# - [1.6k/1.6k files][ 24.7 MiB/ 24.7 MiB] 100% Done 770.3 KiB/s ETA 00:00:00
# Operation completed over 1.6k objects/24.7 MiB.

# %%
# !pip install ffmpeg-python
# Out:
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.6/dist-packages (0.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from ffmpeg-python) (0.16.0)

# %%
#!ls /content/
# !ls nlp_keyword_bucket/data_dir/okugimusaظ4bf67566b0944663b741b361f12d80a7_10840aa4411a4e5d99fc95c365c10e5c.wav
# Out:
# 4bf67566b0944663b741b361f12d80a7_10840aa4411a4e5d99fc95c365c10e5c.wav
# 4bf67566b0944663b741b361f12d80a7_3a62a9e875d04fceb485bf101903c471.wav
# 4bf67566b0944663b741b361f12d80a7_42e124e8d24c44759bce828b6f8c3c42.wav
# 4bf67566b0944663b741b361f12d80a7_5034a9791e5a4989bd1f558cac447680.wav
# 4bf67566b0944663b741b361f12d80a7_53604bb4295b4abab29bea76503a030f.wav
# 4bf67566b0944663b741b361f12d80a7_8b56e46462e944bda00f7ba6f94b496e.wav
# 4bf67566b0944663b741b361f12d80a7_9a851ff201bf4adf879c23a26acf97ef.wav
# 4bf67566b0944663b741b361f12d80a7_cac1558abc0f4eac92bac413ea48f80b.wav
# 4bf67566b0944663b741b361f12d80a7_f127b039ff164816b9c0e1a8ae572a96.wav
# 4db337b1ecbd4a67bbecbd503d74750a_1263da6f3ad6419b922c1c216cf821d2.wav
# 4db337b1ecbd4a67bbecbd503d74750a_27598aad366546488ca44981f6fb2d1a.wav
# 4db337b1ecbd4a67bbecbd503d74750a_7d66741980a244a28be5d0fa9d572d17.wav
# 4db337b1ecbd4a67bbecbd503d74750a_7f21724bccc141fc96b4235081b3c52e.wav
# 4db337b1ecbd4a67bbecbd503d74750a_a57f6e9882f2443889cbca41adaa070e.wav
# 4db337b1ecbd4a67bbecbd503d74750a_c28392ef4f7b4cad80e85929da66d4a9.wav
# 4db337b1ecbd4a67bbecbd503d74750a_c61dfb90eb7c401c96ab519e6eaad329.wav
# c5043d1a91124c3aa60750b78447e6dc_0f44498f0b57448f9e3c2ea2b7584080.wav
# c5043d1a91124c3aa60750b78447e6dc_c0c93b410d544a4ba41b0881438fc573.wav

# %%
import os
wavfiles = [os.path.join(root, name)
             for root, dirs, files in os.walk("/content/nlp_keyword_bucket/")
             for name in files
             if name.endswith((".wav"))]

for filename in wavfiles:
  os.system("ffmpeg -y -i {0} {0}".format(filename))

# %%
# %matplotlib inline
import IPython.display
from ipywidgets import interact, interactive, fixed

# Packages we're using
import numpy as np
import matplotlib.pyplot as plt
import copy
from scipy.io import wavfile
from scipy.signal import butter, lfilter
import scipy.ndimage

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype="band")
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y


def overlap(X, window_size, window_step):
    """
    Create an overlapped version of X
    Parameters
    ----------
    X : ndarray, shape=(n_samples,)
        Input signal to window and overlap
    window_size : int
        Size of windows to take
    window_step : int
        Step size between windows
    Returns
    -------
    X_strided : shape=(n_windows, window_size)
        2D array of overlapped X
    """
    if window_size % 2 != 0:
        raise ValueError("Window size must be even!")
    # Make sure there are an even number of windows before stridetricks
    append = np.zeros((window_size - len(X) % window_size))
    X = np.hstack((X, append))

    ws = window_size
    ss = window_step
    a = X

    valid = len(a) - ws
    nw = (valid) // ss
    out = np.ndarray((nw, ws), dtype=a.dtype)

    for i in np.arange(nw):
        # "slide" the window along the samples
        start = i * ss
        stop = start + ws
        out[i] = a[start:stop]

    return out


def stft(
    X, fftsize=128, step=65, mean_normalize=True, real=False, compute_onesided=True
):
    """
    Compute STFT for 1D real valued input X
    """
    if real:
        local_fft = np.fft.rfft
        cut = -1
    else:
        local_fft = np.fft.fft
        cut = None
    if compute_onesided:
        cut = fftsize // 2
    if mean_normalize:
        X -= X.mean()

    X = overlap(X, fftsize, step)

    size = fftsize
    win = 0.54 - 0.46 * np.cos(2 * np.pi * np.arange(size) / (size - 1))
    X = X * win[None]
    X = local_fft(X)[:, :cut]
    return X


def pretty_spectrogram(d, log=True, thresh=5, fft_size=512, step_size=64):
    """
    creates a spectrogram
    log: take the log of the spectrgram
    thresh: threshold minimum power for log spectrogram
    """
    specgram = np.abs(
        stft(d, fftsize=fft_size, step=step_size, real=False, compute_onesided=True)
    )

    if log == True:
        specgram /= specgram.max()  # volume normalize to max 1
        specgram = np.log10(specgram)  # take log
        specgram[
            specgram < -thresh
        ] = -thresh  # set anything less than the threshold as the threshold
    else:
        specgram[
            specgram < thresh
        ] = thresh  # set anything less than the threshold as the threshold

    return specgram


# Also mostly modified or taken from https://gist.github.com/kastnerkyle/179d6e9a88202ab0a2fe
def invert_pretty_spectrogram(
    X_s, log=True, fft_size=512, step_size=512 / 4, n_iter=10
):

    if log == True:
        X_s = np.power(10, X_s)

    X_s = np.concatenate([X_s, X_s[:, ::-1]], axis=1)
    X_t = iterate_invert_spectrogram(X_s, fft_size, step_size, n_iter=n_iter)
    return X_t


def iterate_invert_spectrogram(X_s, fftsize, step, n_iter=10, verbose=False):
    """
    Under MSR-LA License
    Based on MATLAB implementation from Spectrogram Inversion Toolbox
    References
    ----------
    D. Griffin and J. Lim. Signal estimation from modified
    short-time Fourier transform. IEEE Trans. Acoust. Speech
    Signal Process., 32(2):236-243, 1984.
    Malcolm Slaney, Daniel Naar and Richard F. Lyon. Auditory
    Model Inversion for Sound Separation. Proc. IEEE-ICASSP,
    Adelaide, 1994, II.77-80.
    Xinglei Zhu, G. Beauregard, L. Wyse. Real-Time Signal
    Estimation from Modified Short-Time Fourier Transform
    Magnitude Spectra. IEEE Transactions on Audio Speech and
    Language Processing, 08/2007.
    """
    reg = np.max(X_s) / 1e8
    X_best = copy.deepcopy(X_s)
    for i in range(n_iter):
        if verbose:
            print("Runnning iter %i" % i)
        if i == 0:
            X_t = invert_spectrogram(
                X_best, step, calculate_offset=True, set_zero_phase=True
            )
        else:
            # Calculate offset was False in the MATLAB version
            # but in mine it massively improves the result
            # Possible bug in my impl?
            X_t = invert_spectrogram(
                X_best, step, calculate_offset=True, set_zero_phase=False
            )
        est = stft(X_t, fftsize=fftsize, step=step, compute_onesided=False)
        phase = est / np.maximum(reg, np.abs(est))
        X_best = X_s * phase[: len(X_s)]
    X_t = invert_spectrogram(X_best, step, calculate_offset=True, set_zero_phase=False)
    return np.real(X_t)


def invert_spectrogram(X_s, step, calculate_offset=True, set_zero_phase=True):
    """
    Under MSR-LA License
    Based on MATLAB implementation from Spectrogram Inversion Toolbox
    References
    ----------
    D. Griffin and J. Lim. Signal estimation from modified
    short-time Fourier transform. IEEE Trans. Acoust. Speech
    Signal Process., 32(2):236-243, 1984.
    Malcolm Slaney, Daniel Naar and Richard F. Lyon. Auditory
    Model Inversion for Sound Separation. Proc. IEEE-ICASSP,
    Adelaide, 1994, II.77-80.
    Xinglei Zhu, G. Beauregard, L. Wyse. Real-Time Signal
    Estimation from Modified Short-Time Fourier Transform
    Magnitude Spectra. IEEE Transactions on Audio Speech and
    Language Processing, 08/2007.
    """
    size = int(X_s.shape[1] // 2)
    wave = np.zeros((X_s.shape[0] * step + size))
    # Getting overflow warnings with 32 bit...
    wave = wave.astype("float64")
    total_windowing_sum = np.zeros((X_s.shape[0] * step + size))
    win = 0.54 - 0.46 * np.cos(2 * np.pi * np.arange(size) / (size - 1))

    est_start = int(size // 2) - 1
    est_end = est_start + size
    for i in range(X_s.shape[0]):
        wave_start = int(step * i)
        wave_end = wave_start + size
        if set_zero_phase:
            spectral_slice = X_s[i].real + 0j
        else:
            # already complex
            spectral_slice = X_s[i]

        # Don't need fftshift due to different impl.
        wave_est = np.real(np.fft.ifft(spectral_slice))[::-1]
        if calculate_offset and i > 0:
            offset_size = size - step
            if offset_size <= 0:
                print(
                    "WARNING: Large step size >50\% detected! "
                    "This code works best with high overlap - try "
                    "with 75% or greater"
                )
                offset_size = step
            offset = xcorr_offset(
                wave[wave_start : wave_start + offset_size],
                wave_est[est_start : est_start + offset_size],
            )
        else:
            offset = 0
        wave[wave_start:wave_end] += (
            win * wave_est[est_start - offset : est_end - offset]
        )
        total_windowing_sum[wave_start:wave_end] += win
    wave = np.real(wave) / (total_windowing_sum + 1e-6)
    return wave


def xcorr_offset(x1, x2):
    """
    Under MSR-LA License
    Based on MATLAB implementation from Spectrogram Inversion Toolbox
    References
    ----------
    D. Griffin and J. Lim. Signal estimation from modified
    short-time Fourier transform. IEEE Trans. Acoust. Speech
    Signal Process., 32(2):236-243, 1984.
    Malcolm Slaney, Daniel Naar and Richard F. Lyon. Auditory
    Model Inversion for Sound Separation. Proc. IEEE-ICASSP,
    Adelaide, 1994, II.77-80.
    Xinglei Zhu, G. Beauregard, L. Wyse. Real-Time Signal
    Estimation from Modified Short-Time Fourier Transform
    Magnitude Spectra. IEEE Transactions on Audio Speech and
    Language Processing, 08/2007.
    """
    x1 = x1 - x1.mean()
    x2 = x2 - x2.mean()
    frame_size = len(x2)
    half = frame_size // 2
    corrs = np.convolve(x1.astype("float32"), x2[::-1].astype("float32"))
    corrs[:half] = -1e30
    corrs[-half:] = -1e30
    offset = corrs.argmax() - len(x1)
    return offset


def make_mel(spectrogram, mel_filter, shorten_factor=1):
    mel_spec = np.transpose(mel_filter).dot(np.transpose(spectrogram))
    mel_spec = scipy.ndimage.zoom(
        mel_spec.astype("float32"), [1, 1.0 / shorten_factor]
    ).astype("float16")
    mel_spec = mel_spec[:, 1:-1]  # a little hacky but seemingly needed for clipping
    return mel_spec


def mel_to_spectrogram(mel_spec, mel_inversion_filter, spec_thresh, shorten_factor):
    """
    takes in an mel spectrogram and returns a normal spectrogram for inversion 
    """
    mel_spec = mel_spec + spec_thresh
    uncompressed_spec = np.transpose(np.transpose(mel_spec).dot(mel_inversion_filter))
    uncompressed_spec = scipy.ndimage.zoom(
        uncompressed_spec.astype("float32"), [1, shorten_factor]
    ).astype("float16")
    uncompressed_spec = uncompressed_spec - 4
    return uncompressed_spec


# From https://github.com/jameslyons/python_speech_features


def hz2mel(hz):
    """Convert a value in Hertz to Mels
    :param hz: a value in Hz. This can also be a numpy array, conversion proceeds element-wise.
    :returns: a value in Mels. If an array was passed in, an identical sized array is returned.
    """
    return 2595 * np.log10(1 + hz / 700.0)


def mel2hz(mel):
    """Convert a value in Mels to Hertz
    :param mel: a value in Mels. This can also be a numpy array, conversion proceeds element-wise.
    :returns: a value in Hertz. If an array was passed in, an identical sized array is returned.
    """
    return 700 * (10 ** (mel / 2595.0) - 1)


def get_filterbanks(nfilt=20, nfft=512, samplerate=16000, lowfreq=0, highfreq=None):
    """Compute a Mel-filterbank. The filters are stored in the rows, the columns correspond
    to fft bins. The filters are returned as an array of size nfilt * (nfft/2 + 1)
    :param nfilt: the number of filters in the filterbank, default 20.
    :param nfft: the FFT size. Default is 512.
    :param samplerate: the samplerate of the signal we are working with. Affects mel spacing.
    :param lowfreq: lowest band edge of mel filters, default 0 Hz
    :param highfreq: highest band edge of mel filters, default samplerate/2
    :returns: A numpy array of size nfilt * (nfft/2 + 1) containing filterbank. Each row holds 1 filter.
    """
    highfreq = highfreq or samplerate / 2
    assert highfreq <= samplerate / 2, "highfreq is greater than samplerate/2"

    # compute points evenly spaced in mels
    lowmel = hz2mel(lowfreq)
    highmel = hz2mel(highfreq)
    melpoints = np.linspace(lowmel, highmel, nfilt + 2)
    # our points are in Hz, but we use fft bins, so we have to convert
    #  from Hz to fft bin number
    bin = np.floor((nfft + 1) * mel2hz(melpoints) / samplerate)

    fbank = np.zeros([nfilt, nfft // 2])
    for j in range(0, nfilt):
        for i in range(int(bin[j]), int(bin[j + 1])):
            fbank[j, i] = (i - bin[j]) / (bin[j + 1] - bin[j])
        for i in range(int(bin[j + 1]), int(bin[j + 2])):
            fbank[j, i] = (bin[j + 2] - i) / (bin[j + 2] - bin[j + 1])
    return fbank


def create_mel_filter(
    fft_size, n_freq_components=64, start_freq=300, end_freq=8000, samplerate=44100
):
    """
    Creates a filter to convolve with the spectrogram to get out mels

    """
    mel_inversion_filter = get_filterbanks(
        nfilt=n_freq_components,
        nfft=fft_size,
        samplerate=samplerate,
        lowfreq=start_freq,
        highfreq=end_freq,
    )
    # Normalize filter
    mel_filter = mel_inversion_filter.T / mel_inversion_filter.sum(axis=1)

    return mel_filter, mel_inversion_filter

# %%
### Parameters ###
fft_size = 2048  # window size for the FFT
step_size = fft_size // 16  # distance to slide along the window (in time)
spec_thresh = 4  # threshold for spectrograms (lower filters out more noise)
lowcut = 500  # Hz # Low cut for our butter bandpass filter
highcut = 15000  # Hz # High cut for our butter bandpass filter
# For mels
n_mel_freq_components = 64  # number of mel frequency channels
shorten_factor = 10  # how much should we compress the x-axis (time)
start_freq = 300  # Hz # What frequency to start sampling our melS from
end_freq = 8000  # Hz # What frequency to stop sampling our melS from

# %%
# Grab your wav and filter it
mywav = ""
rate, data = wavfile.read(mywav)
data = butter_bandpass_filter(data, lowcut, highcut, rate, order=1)
# Only use a short clip for our demo
if np.shape(data)[0] / float(rate) > 10:
    data = data[0 : rate * 10]
print("Length in time (s): ", np.shape(data)[0] / float(rate))
# Play the audio
IPython.display.Audio(data=data, rate=rate)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-1e78e791cb18> in <module>()
#       1 mywav = "nlp_keyword_bucket/data_dir/okugimusaظ4bf67566b0944663b741b361f12d80a7_10840aa4411a4e5d99fc95c365c10e5c.wav"
# ----> 2 rate, data = wavfile.read(mywav)
#       3 data = butter_bandpass_filter(data, lowcut, highcut, rate, order=1)
#       4 # Only use a short clip for our demo
#       5 if np.shape(data)[0] / float(rate) > 10:
#
# /usr/local/lib/python3.6/dist-packages/scipy/io/wavfile.py in read(filename, mmap)
#     231         mmap = False
#     232     else:
# --> 233         fid = open(filename, 'rb')
#     234
#     235     try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nlp_keyword_bucket/data_dir/okugimusaظ4bf67566b0944663b741b361f12d80a7_10840aa4411a4e5d99fc95c365c10e5c.wav'

# %%
wav_spectrogram = pretty_spectrogram(
    data.astype("float64"),
    fft_size=fft_size,
    step_size=step_size,
    log=True,
    thresh=spec_thresh,
)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 4))
cax = ax.matshow(
    np.transpose(wav_spectrogram),
    interpolation="nearest",
    aspect="auto",
    cmap=plt.cm.afmhot,
    origin="lower",
)
fig.colorbar(cax)
plt.title("Original Spectrogram")
# Out:
# Text(0.5, 1.05, 'Original Spectrogram')
